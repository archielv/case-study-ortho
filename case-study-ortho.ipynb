# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as pl
import seaborn as sns
import warnings

# %%
# %matplotlib inline

# %%
# Data folder
data_dir = r'C:\Users\archi\case-study\ortho'

# %%
# List files in filder

for files in os.listdir(data_dir):
    print(files)
# Out:
# AEF54D00
# CaseStudy_Data.xlsb
# CaseStudy_Data.xlsx
# CaseStudy_Instructions.pptx
# DSI_CaseStudy.zip
# PD_HCM_Senior_Data_Scientist_20220309.pdf
# ~$CaseStudy_Data.xlsx

# %%
# Folder and Filname

orthofile = data_dir + '\\' + 'CaseStudy_Data.xlsx'

# %%
ortho_df = pd.read_excel(orthofile,engine='openpyxl',sheet_name='Data')

# %%
ortho_df.describe(include='all').T
# Out:
# C:\Users\archi\AppData\Local\Temp/ipykernel_23688/675056587.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   ortho_df.describe(include='all').T
#                         count unique                  top   freq      first  \
# personid              58381.0    NaN                  NaN    NaN        NaT
# agegrp                  58381     10                70-74  11934        NaT
# sex                     58381      2                    F  32162        NaT
# hospproduct             58377      7                 Gold  48307        NaT
# tenurecoveryears      58381.0    NaN                  NaN    NaN        NaT
# hist_cancer           58381.0    NaN                  NaN    NaN        NaT
# hist_obesity          58381.0    NaN                  NaN    NaN        NaT
# ...

# %%
from pandas_profiling import ProfileReport

# %%
orthoprofile = ProfileReport(ortho_df)
orthoprofile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
